# %% [markdown]
# # Get geocode for a given zip code
# 1. find unique zip
# 2. get their lat,lng
# 3. acquire the list of parks nearby

# %%
import numpy as np
import pandas as pd
import requests
from time import sleep
import utility
import matplotlib.pyplot as plt

# %%
info_df_wt_fsq_type = pd.read_parquet('park_feature_with_predpop.parquet')
info_df_wt_fsq_type = info_df_wt_fsq_type[~np.isnan(info_df_wt_fsq_type['lat'])]
info_df_wt_fsq_type.loc[np.where(info_df_wt_fsq_type['pred_pop_residual']>150)[0],'pred_pop_residual'] = 150
info_df_wt_fsq_type.loc[np.where(info_df_wt_fsq_type['pred_pop_residual']<-150)[0],'pred_pop_residual'] = -150
info_df_wt_fsq_type = info_df_wt_fsq_type[info_df_wt_fsq_type['fsq_type_name_simplified'] != 'Shop & Service']

info_df_wt_fsq_type.head()
# Out:
#                             id  \
# 0  ChIJAWkAqNL1t4kRlm4slspOSXo
# 1  ChIJzcow6Xb1t4kRQVE7s1AWWr8
# 2  ChIJ_bk5K1z1t4kRQNverIUOVko
# 3  ChIJ_-2cQEX1t4kRoiCrmNMbrQ8
# 4  ChIJQWcsgIn2t4kRCL0Ub363FyI
#
#                                                 name  rating        lat  \
# 0                                  Quiet Waters Park     4.7  38.937670
# 1                   Hillsmere Shores Community Beach     5.0  38.927212
# 2                             Quiet Waters Dog Beach     4.7  38.930202
# 3                              Quiet Waters Dog Park     4.8  38.931865
# 4  Pip Moyer Recreation Center (Annapolis Recreat...     4.5  38.963271
#
#          lng                                            address  address_city  \
# 0 -76.500899  600 Quiet Waters Park Rd, Annapolis, MD 21403,...  Annapolis,MD
# 1 -76.494150        101 W Bay View Dr, Annapolis, MD 21403, USA  Annapolis,MD
# 2 -76.508341  1701-1799 Quiet Waters Park Rd, Annapolis, MD ...  Annapolis,MD
# 3 -76.505658  600 Quiet Waters Park Rd, Annapolis, MD 21403,...  Annapolis,MD
# 4 -76.505150           273 Hilltop Ln, Annapolis, MD 21403, USA  Annapolis,MD
#
#   fsq_type_name_simplified  pred_pop_residual
# 0                     Park         -10.157161
# 1               Playground                NaN
# 2                     None           9.330558
# 3                  Dog Run                NaN
# 4       Athletics & Sports         -21.618591

# %%
# info_df_wt_fsq_type.to_parquet('park_feature_with_predpop_clean.parquet')

# %% [markdown]
# ## Find unique zip

# %%
import re
def get_zip(address):
    if address is not None:
        add_regex = r'(\d{5}), USA|United States'
        zipcode = re.search(add_regex, address)
        if zipcode is not None:
            zipcode = zipcode[1]
            return zipcode
        else:
            print(f"Didn't find zip for: {address}")

# %%
zipcode_all = info_df_wt_fsq_type['address'].apply(get_zip)
zipcode_geo = pd.DataFrame({'zipcode':zipcode_all})
zipcode_geo['address_city'] = info_df_wt_fsq_type['address_city']
zipcode_geo.drop_duplicates(inplace=True)  # (subset='zipcode', )sometimes one zip mapped to multiple cities, keep the first one
zipcode_geo.dropna(inplace=True)
zipcode_geo.reset_index(inplace=True)
# Out:
# Didn't find zip for: Gifford Pinchot State Park, Warrington Township, PA, USA
# Didn't find zip for: Brooklyn, NY, USA
# Didn't find zip for: New York, NY, USA
# Didn't find zip for: New York, NY, USA
# Didn't find zip for: Babylon, NY, USA

# %%
zipcode_geo.shape
# Out:
# (1146, 3)

# %%
def geocode_zip_us(zipcode):
    params = { 'format'        :'json',    #API specific
               'addressdetails': 0, 
               'country'       : 'US',
               'postalcode'    : zipcode }
    headers = { 'user-agent'   : 'parkFinder' }   #  Need to supply a user agent other than the default provided 
                                           #  by requests for the API to accept the query.
    sleep(.1)
    result = requests.get('http://nominatim.openstreetmap.org/search', params=params, headers=headers)
    if len(result.json()) > 0:
        return result.json()[0]['lat'], result.json()[0]['lon']
    else:
        print(zipcode)

# %%
# for the zip codes that were not found by `geocode_zip`
zip_more = ['21402', '21220', '18031', '19060', '08098', '08085', '08085', '19462', '19444', '08066', '08086',
            '08093', '15677', '16901', '07075', '10911', '07732', '11694', '11375', '11435', '11422', '11581']

zip_geo_more = [geocode_zip_us(zipcode) for zipcode in zip_more]

# %%
zipcode_geo_2 = pd.DataFrame({'zipcode':zip_more})
zipcode_geo_2['lat'] = [x[0] if x is not None else None for x in zip_geo_more]
zipcode_geo_2['lng'] = [x[1] if x is not None else None for x in zip_geo_more]
zipcode_geo_2.dropna(inplace=True)

# %%
def geocode_zip(zip_info):
    '''
    zip_info: contains both info on zipcode and city, state
    
    '''
    if zip_info is not None:
        zipcode, city = zip_info                   # get info about the address
        city = city.split(',')
        params = { 'format'        :'json',    #API specific
                   'addressdetails': 0, 
                   'city'          : city[0],
                   'state'         : city[1],
                   'country'       : 'US',
                   'postalcode'    : zipcode}
        headers = { 'user-agent'   : 'parkFinder' }   #  Need to supply a user agent other than the default provided 
                                               #  by requests for the API to accept the query.
        sleep(.1)
        result = requests.get('http://nominatim.openstreetmap.org/search', params=params, headers=headers)
        if len(result.json()) > 0:
            return result.json()[0]['lat'], result.json()[0]['lon']
        else:
            print(zipcode)
    else:
        return None

# %%
zip_geo = zipcode_geo[['zipcode', 'address_city']].apply(geocode_zip, axis=1)

zipcode_geo['lat'] = [x[0] if x is not None else None for x in zip_geo]
zipcode_geo['lng'] = [x[1] if x is not None else None for x in zip_geo]

zipcode_geo.dropna(inplace=True)
# Out:
# 21402
# 21220
# 18031
# 19060
# 08098
# 08085
# 08085
# 19462
# 19444
# 08066
# 08086
# 08093
# 16901
# 07075
# 10911
# 07732
# 11694
# 11375
# 11435
# 11422
# 11581

# %%
# zipcode_geo.to_parquet('zipcode_geo.parquet')

# zipcode_geo = pd.read_parquet('parkFinderZip/zipcode_geo.parquet')

# %%
zipcode_geo.head()
# Out:
#    index zipcode      address_city         lat          lng  \
# 0    0.0   21403      Annapolis,MD  38.9786401   -76.492786
# 1    7.0   21401      Annapolis,MD  38.9786401   -76.492786
# 2   10.0   21409      Annapolis,MD  38.9786401   -76.492786
# 3   15.0   21012         Arnold,MD  39.0320784  -76.5025431
# 4   16.0   21122  Riviera Beach,MD   39.163942  -76.5065982
#
#                                         nearby_parks  number_nearby_parks
# 0  [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   43
# 1  [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   43
# 2  [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   43
# 3  [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   45
# 4  [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   55

# %% [markdown]
# ## Acquire the list of parks that are nearby

# %%
distance_threshold_miles = 40

def get_nearby_parks(geo_lat_lng):
    lat, long = map(float, geo_lat_lng)
    df_tmp = info_df_wt_fsq_type[(info_df_wt_fsq_type[['lat', 'lng']].apply(
        utility.lat_lng_dist, axis=1, args=((lat, long),)) < distance_threshold_miles) & 
                             (~np.isnan(info_df_wt_fsq_type['pred_pop_residual']))]
    return list(df_tmp['id'])

# %%
zipcode_geo['nearby_parks'] = zipcode_geo[['lat', 'lng']].apply(get_nearby_parks, axis=1)

# zipcode_geo_2['nearby_parks'] = zipcode_geo_2[['lat', 'lng']].apply(get_nearby_parks, axis=1)

# %%
# zipcode_geo = zipcode_geo.append(zipcode_geo_2)
zipcode_geo = zipcode_geo.reset_index(drop=True)

# %%
zipcode_geo['number_nearby_parks'] = zipcode_geo['nearby_parks'].apply(lambda x: len(x))

# %%
zipcode_geo
# Out:
#       index zipcode      address_city                 lat                 lng  \
# 0       0.0   21403      Annapolis,MD          38.9786401          -76.492786
# 1       7.0   21401      Annapolis,MD          38.9786401          -76.492786
# 2      10.0   21409      Annapolis,MD          38.9786401          -76.492786
# 3      15.0   21012         Arnold,MD          39.0320784         -76.5025431
# 4      16.0   21122  Riviera Beach,MD           39.163942         -76.5065982
# ...     ...     ...               ...                 ...                 ...
# 1142    NaN   11694               NaN   40.57741976779516  -73.84673104881777
# 1143    NaN   11375               NaN   40.71939841194838  -73.84789022426511
# 1144    NaN   11435               NaN  40.699611878308914  -73.80841501242986
# 1145    NaN   11422               NaN     40.663506792796  -73.73533585142457
# 1146    NaN   11581               NaN   40.65248899616516  -73.71172144874048
#
#                                            nearby_parks  number_nearby_parks
# 0     [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   52
# 1     [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   52
# 2     [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   52
# 3     [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   55
# 4     [ChIJAWkAqNL1t4kRlm4slspOSXo, ChIJ_bk5K1z1t4kR...                   65
# ...                                                 ...                  ...
# 1142  [ChIJDbzqHhXFw4kR5dCbhMQVy7Q, ChIJKw0kXxHGw4kR...                 1073
# 1143  [ChIJDbzqHhXFw4kR5dCbhMQVy7Q, ChIJKw0kXxHGw4kR...                 1115
# 1144  [ChIJDbzqHhXFw4kR5dCbhMQVy7Q, ChIJKw0kXxHGw4kR...                 1108
# 1145  [ChIJKw0kXxHGw4kRn0bEGob21as, ChIJKYT7QWbGw4kR...                 1098
# 1146  [ChIJKw0kXxHGw4kRn0bEGob21as, ChIJe0JPXDfGw4kR...                 1091
#
# [1147 rows x 7 columns]

# %% [markdown]
# ## Combine with inaturallist info

# %%
info_with_inaturalist = pd.read_parquet('inaturalist/park_info_with_inaturalist.parquet')

# %%
def maxmin_norm(data):
    return (data - data.min())/(data.max() - data.min())

def extract_nearby_zip(zipcode='19103'):
    park_ids = zipcode_geo[zipcode_geo['zipcode']==zipcode]['nearby_parks'].iloc[0]
    df_tmp = info_df_wt_fsq_type[info_df_wt_fsq_type['id'].isin(park_ids)]
    df_tmp = df_tmp.merge(info_with_inaturalist, how='left', on=['id', 'name', 'lat', 'lng', 'address'])
    df_tmp.dropna(subset=['species_count'], inplace=True)
    df_tmp.reset_index(drop=True, inplace=True)
    # clean up data
    df_tmp.loc[np.where(df_tmp['species_count']>1500)[0],'species_count'] = 1500
    # normalize 
    df_tmp['species_count_norm'] = maxmin_norm(df_tmp['species_count'])
    df_tmp['rating_norm'] = maxmin_norm(df_tmp['rating'])
    df_tmp['traffic_norm'] = maxmin_norm(-df_tmp['pred_pop_residual'])
    
    df_tmp['total_score'] = df_tmp['species_count_norm'] + df_tmp['traffic_norm'] + df_tmp['rating_norm']
    df_tmp = df_tmp.sort_values(by=['total_score'], ascending=False)

    return df_tmp

# %%
zipcode = '11581'
df_tmp = extract_nearby_zip(zipcode)
df_tmp[:10]
# Out:
#                               id                           name  rating  \
# 96   ChIJQwRohxBbwokRmHrfAMb3ixc                  Prospect Park     4.7
# 74   ChIJH5q1BzpawokR4ffTuJzssbQ  Brooklyn Bridge Park - Pier 1     4.8
# 119  ChIJ32XY7h_2wokRXb54DHKYs00                   North Meadow     4.7
# 217  ChIJCS0YquRhwokRO78O2n8USsc                   Oakland Lake     4.6
# 100  ChIJYfjRMQlbwokRUkgY4QX62_4               Vale of Cashmere     4.7
# 258  ChIJd7iQrJBYwokROrpPbxeQsUc                 The Great Lawn     4.7
# 71   ChIJkwX1AjdawokRx9reOccHFr4     Brooklyn Heights Promenade     4.8
# 124  ChIJKZJlmqBYwokR8eWdVsifED8                    East Meadow     4.6
# 224  ChIJzyx69P9hwokRMP73UTW2hTA                Alley Pond Park     4.6
# 160  ChIJyRUHuHzzwokRPxVBNKhcP9c      New York Botanical Garden     4.7
#
#            lat        lng                                            address  \
# 96   40.660204 -73.968956                                  Brooklyn, NY, USA
# 74   40.702961 -73.994926               2 Furman St, Brooklyn, NY 11201, USA
# 119  40.792136 -73.958285         102nd St Crossing, New York, NY 10029, USA
# 217  40.758091 -73.760181           56th Ave, Oakland Gardens, NY 11364, USA
# 100  40.668765 -73.968237             Prospect Park, Brooklyn, NY 11238, USA
# 258  40.781692 -73.966419  79th Street & 85th Street, New York, NY 10024,...
# 71   40.696194 -73.997504  Montague St &, Pierrepont Pl, Brooklyn, NY 112...
# 124  40.790096 -73.955739                   5th Ave, New York, NY 10029, USA
# 224  40.742395 -73.738434         Union Tpke, Oakland Gardens, NY 11364, USA
# 160  40.861705 -73.880690       2900 Southern Blvd, The Bronx, NY 10458, USA
#
#            address_city fsq_type_name_simplified  pred_pop_residual  \
# 96          Brooklyn,NY                     Park         -10.486436
# 74          Brooklyn,NY       Travel & Transport          -0.300978
# 119         New York,NY                    Field          -2.413114
# 217  Oakland Gardens,NY                     Lake         -22.658120
# 100         Brooklyn,NY                   Garden           4.055384
# 258         New York,NY                    Field           7.220463
# 71          Brooklyn,NY           Scenic Lookout         -15.712900
# 124         New York,NY                    Field          -5.689636
# 224  Oakland Gardens,NY                     Park          -3.745140
# 160        The Bronx,NY                   Garden          14.805693
#
#      inat_nb_place_id  ...  Actinopterygii  Animalia Amphibia  Mollusca  \
# 96                NaN  ...             NaN       NaN     32.0       NaN
# 74           144399.0  ...            11.0      32.0      NaN       NaN
# 119           49955.0  ...             NaN       NaN      NaN       NaN
# 217          125376.0  ...            12.0       NaN    123.0       NaN
# 100           55174.0  ...             NaN       NaN     32.0       NaN
# 258          125404.0  ...             NaN       NaN      NaN       NaN
# 71            64626.0  ...            22.0      22.0      NaN       NaN
# 124           49955.0  ...             NaN       NaN      NaN       NaN
# 224               NaN  ...             NaN       NaN    127.0       NaN
# 160               NaN  ...             NaN       NaN     43.0       NaN
#
#      Protozoa  Chromista  species_count_norm  rating_norm traffic_norm  \
# 96        NaN        NaN            1.000000     0.909091     0.805343
# 74        NaN        NaN            0.951333     1.000000     0.754231
# 119       NaN        NaN            1.000000     0.909091     0.764830
# 217       NaN        NaN            0.975333     0.818182     0.866422
# 100       NaN        NaN            1.000000     0.909091     0.732370
# 258       NaN        NaN            1.000000     0.909091     0.716487
# 71        NaN        NaN            0.784000     1.000000     0.831570
# 124       NaN        NaN            1.000000     0.818182     0.781272
# 224       NaN        NaN            1.000000     0.818182     0.771514
# 160       NaN        NaN            1.000000     0.909091     0.678423
#
#      total_score
# 96      2.714433
# 74      2.705564
# 119     2.673920
# 217     2.659937
# 100     2.641461
# 258     2.625578
# 71      2.615570
# 124     2.599453
# 224     2.589696
# 160     2.587514
#
# [10 rows x 39 columns]
